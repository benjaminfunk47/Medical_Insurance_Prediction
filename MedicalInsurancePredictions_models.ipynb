# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import pickle
from pycaret.regression import *
from pycaret.utils import version

# %%
df = pd.read_csv('df_with_target.csv')

df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges',
#        'sex_encoded', 'smoker_encoded', 'region_encoded'],
#       dtype='object')

# %%
df.shape
# Out:
# (1327, 10)

# %% [markdown]
# # Seperate Columns

# %%
ignore_features = ['sex', 'region', 'smoker']

categorical_features = ['smoker_encoded', 'region_encoded',
                        'sex_encoded', 'children', ]

numeric_features = ['age', 'bmi']

# %% [markdown]
# # Scale the Numerical Columns

# %%
# Create a StandardScaler object
scaler = StandardScaler()

# Fit and Transform numeric features on the scaler
df[numeric_features] = scaler.fit_transform(df[numeric_features])

# save the scaler
with open('df_scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
# Creation Regression Experiment
exp = RegressionExperiment()

# Training with 80/20 split, ignoring non-encoded categorical features, setting categorical and numerical features, set the target variable, allowing shuffling with 5 folds
exp.setup(df, 
          ignore_features=ignore_features,
          categorical_features=categorical_features,
          numeric_features=numeric_features,
          target='charges',
          train_size=0.8,
          fold_shuffle=True,
          fold=5,
         )
# Out:
# <style type="text/css">
# #T_2cdab_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2cdab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cdab_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2cdab_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cdab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2cdab_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2cdab_row0_col1" class="data row0 col1" >2136</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2cdab_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2cdab_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2cdab_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2cdab_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2cdab_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_2cdab_row3_col1" class="data row3 col1" >(1327, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2cdab_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_2cdab_row4_col1" class="data row4 col1" >(1327, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2cdab_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_2cdab_row5_col1" class="data row5 col1" >(1061, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2cdab_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_2cdab_row6_col1" class="data row6 col1" >(266, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2cdab_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_2cdab_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2cdab_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_2cdab_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2cdab_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_2cdab_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2cdab_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_2cdab_row10_col1" class="data row10 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2cdab_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_2cdab_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2cdab_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_2cdab_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2cdab_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_2cdab_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2cdab_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_2cdab_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2cdab_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_2cdab_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2cdab_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_2cdab_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2cdab_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_2cdab_row17_col1" class="data row17 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2cdab_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_2cdab_row18_col1" class="data row18 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2cdab_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_2cdab_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_2cdab_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_2cdab_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_2cdab_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_2cdab_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_2cdab_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_2cdab_row22_col1" class="data row22 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2cdab_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_2cdab_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_2cdab_row23_col1" class="data row23 col1" >2b3f</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Compare models
exp.compare_models()
# Out:
# <style type="text/css">
# #T_02dce th {
#   text-align: left;
# }
# #T_02dce_row0_col0, #T_02dce_row0_col6, #T_02dce_row1_col0, #T_02dce_row1_col1, #T_02dce_row1_col2, #T_02dce_row1_col3, #T_02dce_row1_col4, #T_02dce_row1_col5, #T_02dce_row1_col6, #T_02dce_row2_col0, #T_02dce_row2_col1, #T_02dce_row2_col2, #T_02dce_row2_col3, #T_02dce_row2_col4, #T_02dce_row2_col5, #T_02dce_row2_col6, #T_02dce_row3_col0, #T_02dce_row3_col1, #T_02dce_row3_col2, #T_02dce_row3_col3, #T_02dce_row3_col4, #T_02dce_row3_col5, #T_02dce_row3_col6, #T_02dce_row4_col0, #T_02dce_row4_col1, #T_02dce_row4_col2, #T_02dce_row4_col3, #T_02dce_row4_col4, #T_02dce_row4_col5, #T_02dce_row4_col6, #T_02dce_row5_col0, #T_02dce_row5_col1, #T_02dce_row5_col2, #T_02dce_row5_col3, #T_02dce_row5_col4, #T_02dce_row5_col5, #T_02dce_row5_col6, #T_02dce_row6_col0, #T_02dce_row6_col1, #T_02dce_row6_col2, #T_02dce_row6_col3, #T_02dce_row6_col4, #T_02dce_row6_col5, #T_02dce_row6_col6, #T_02dce_row7_col0, #T_02dce_row7_col1, #T_02dce_row7_col2, #T_02dce_row7_col3, #T_02dce_row7_col4, #T_02dce_row7_col5, #T_02dce_row7_col6, #T_02dce_row8_col0, #T_02dce_row8_col1, #T_02dce_row8_col2, #T_02dce_row8_col3, #T_02dce_row8_col4, #T_02dce_row8_col5, #T_02dce_row8_col6, #T_02dce_row9_col0, #T_02dce_row9_col1, #T_02dce_row9_col2, #T_02dce_row9_col3, #T_02dce_row9_col4, #T_02dce_row9_col5, #T_02dce_row9_col6, #T_02dce_row10_col0, #T_02dce_row10_col1, #T_02dce_row10_col2, #T_02dce_row10_col3, #T_02dce_row10_col4, #T_02dce_row10_col5, #T_02dce_row10_col6, #T_02dce_row11_col0, #T_02dce_row11_col1, #T_02dce_row11_col2, #T_02dce_row11_col3, #T_02dce_row11_col4, #T_02dce_row11_col5, #T_02dce_row11_col6, #T_02dce_row12_col0, #T_02dce_row12_col1, #T_02dce_row12_col2, #T_02dce_row12_col3, #T_02dce_row12_col4, #T_02dce_row12_col5, #T_02dce_row12_col6, #T_02dce_row13_col0, #T_02dce_row13_col1, #T_02dce_row13_col2, #T_02dce_row13_col3, #T_02dce_row13_col4, #T_02dce_row13_col5, #T_02dce_row14_col0, #T_02dce_row14_col1, #T_02dce_row14_col2, #T_02dce_row14_col3, #T_02dce_row14_col4, #T_02dce_row14_col5, #T_02dce_row14_col6, #T_02dce_row15_col0, #T_02dce_row15_col1, #T_02dce_row15_col2, #T_02dce_row15_col3, #T_02dce_row15_col4, #T_02dce_row15_col5, #T_02dce_row15_col6, #T_02dce_row16_col0, #T_02dce_row16_col1, #T_02dce_row16_col2, #T_02dce_row16_col3, #T_02dce_row16_col4, #T_02dce_row16_col5, #T_02dce_row16_col6, #T_02dce_row17_col0, #T_02dce_row17_col1, #T_02dce_row17_col2, #T_02dce_row17_col3, #T_02dce_row17_col4, #T_02dce_row17_col5, #T_02dce_row17_col6 {
#   text-align: left;
# }
# #T_02dce_row0_col1, #T_02dce_row0_col2, #T_02dce_row0_col3, #T_02dce_row0_col4, #T_02dce_row0_col5, #T_02dce_row13_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_02dce_row0_col7, #T_02dce_row1_col7, #T_02dce_row2_col7, #T_02dce_row3_col7, #T_02dce_row4_col7, #T_02dce_row6_col7, #T_02dce_row8_col7, #T_02dce_row9_col7, #T_02dce_row11_col7, #T_02dce_row12_col7, #T_02dce_row13_col7, #T_02dce_row14_col7, #T_02dce_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_02dce_row5_col7, #T_02dce_row7_col7, #T_02dce_row10_col7, #T_02dce_row15_col7, #T_02dce_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_02dce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02dce_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_02dce_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_02dce_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_02dce_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_02dce_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_02dce_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_02dce_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_02dce_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02dce_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_02dce_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_02dce_row0_col1" class="data row0 col1" >2356.8918</td>
#       <td id="T_02dce_row0_col2" class="data row0 col2" >18692251.3315</td>
#       <td id="T_02dce_row0_col3" class="data row0 col3" >4283.5661</td>
#       <td id="T_02dce_row0_col4" class="data row0 col4" >0.8610</td>
#       <td id="T_02dce_row0_col5" class="data row0 col5" >0.4341</td>
#       <td id="T_02dce_row0_col6" class="data row0 col6" >0.3049</td>
#       <td id="T_02dce_row0_col7" class="data row0 col7" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_02dce_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_02dce_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_02dce_row1_col1" class="data row1 col1" >2529.0894</td>
#       <td id="T_02dce_row1_col2" class="data row1 col2" >20923384.4580</td>
#       <td id="T_02dce_row1_col3" class="data row1 col3" >4540.1109</td>
#       <td id="T_02dce_row1_col4" class="data row1 col4" >0.8449</td>
#       <td id="T_02dce_row1_col5" class="data row1 col5" >0.4733</td>
#       <td id="T_02dce_row1_col6" class="data row1 col6" >0.3411</td>
#       <td id="T_02dce_row1_col7" class="data row1 col7" >0.1160</td>
#     </tr>
#     <tr>
#       <th id="T_02dce_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_02dce_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_02dce_row2_col1" class="data row2 col1" >2691.8778</td>
#       <td id="T_02dce_row2_col2" class="data row2 col2" >21431943.9317</td>
#       <td id="T_02dce_row2_col3" class="data row2 col3" >4598.7797</td>
#       <td id="T_02dce_row2_col4" class="data row2 col4" >0.8412</td>
#       <td id="T_02dce_row2_col5" class="data row2 col5" >0.5368</td>
#       <td id="T_02dce_row2_col6" class="data row2 col6" >0.3667</td>
#       <td id="T_02dce_row2_col7" class="data row2 col7" >0.0640</td>
#     </tr>
#     <tr>
#       <th id="T_02dce_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_02dce_row3_col0" class="data row3 col0" >AdaBoost Regressor</td>
#       <td id="T_02dce_row3_col1" class="data row3 col1" >3670.5956</td>
#       <td id="T_02dce_row3_col2" class="data row3 col2" >23169262.9993</td>
#       <td id="T_02dce_row3_col3" class="data row3 col3" >4799.5709</td>
#       <td id="T_02dce_row3_col4" class="data row3 col4" >0.8299</td>
#       <td id="T_02dce_row3_col5" class="data row3 col5" >0.5843</td>
#       <td id="T_02dce_row3_col6" class="data row3 col6" >0.6292</td>
#       <td id="T_02dce_row3_col7" class="data row3 col7" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_02dce_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_02dce_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_02dce_row4_col1" class="data row4 col1" >2489.4989</td>
#       <td id="T_02dce_row4_col2" class="data row4 col2" >24377979.3788</td>
#       <td id="T_02dce_row4_col3" class="data row4 col3" >4894.6484</td>
#       <td id="T_02dce_row4_col4" class="data row4 col4" >0.8198</td>
#       <td id="T_02dce_row4_col5" class="data row4 col5" >0.4894</td>
#       <td id="T_02dce_row4_col6" class="data row4 col6" >0.3323</td>
#       <td id="T_02dce_row4_col7" class="data row4 col7" >0.0800</td>
#     </tr>
#     <tr>
#       <th id="T_02dce_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_02dce_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_02dce_row5_col1" class="data row5 col1" >4135.2890</td>
#       <td id="T_02dce_row5_col2" class="data row5 col2" >33898638.3832</td>
#       <td id="T_02dce_row5_col3" class="data row5 col3" >5804.1224</td>
#       <td id="T_02dce_row5_col4" class="data row5 col4" >0.7504</td>
#       <td id="T_02dce_row5_col5" class="data row5 col5" >0.5970</td>
#       <td id="T_02dce_row5_col6" class="data row5 col6" >0.4233</td>
#       <td id="T_02dce_row5_col7" class="data
# GradientBoostingRegressor(random_state=2136)

# %%
# Choose model with low RMSE and high R^2 score
gbr_model = exp.create_model('gbr')
# Out:
# <style type="text/css">
# #T_0fa33_row5_col0, #T_0fa33_row5_col1, #T_0fa33_row5_col2, #T_0fa33_row5_col3, #T_0fa33_row5_col4, #T_0fa33_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0fa33">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fa33_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_0fa33_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0fa33_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0fa33_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_0fa33_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_0fa33_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fa33_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0fa33_row0_col0" class="data row0 col0" >2487.9486</td>
#       <td id="T_0fa33_row0_col1" class="data row0 col1" >18815132.0761</td>
#       <td id="T_0fa33_row0_col2" class="data row0 col2" >4337.6413</td>
#       <td id="T_0fa33_row0_col3" class="data row0 col3" >0.8649</td>
#       <td id="T_0fa33_row0_col4" class="data row0 col4" >0.4756</td>
#       <td id="T_0fa33_row0_col5" class="data row0 col5" >0.3664</td>
#     </tr>
#     <tr>
#       <th id="T_0fa33_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0fa33_row1_col0" class="data row1 col0" >2126.3543</td>
#       <td id="T_0fa33_row1_col1" class="data row1 col1" >13608953.3798</td>
#       <td id="T_0fa33_row1_col2" class="data row1 col2" >3689.0315</td>
#       <td id="T_0fa33_row1_col3" class="data row1 col3" >0.9084</td>
#       <td id="T_0fa33_row1_col4" class="data row1 col4" >0.3827</td>
#       <td id="T_0fa33_row1_col5" class="data row1 col5" >0.2741</td>
#     </tr>
#     <tr>
#       <th id="T_0fa33_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0fa33_row2_col0" class="data row2 col0" >2073.0669</td>
#       <td id="T_0fa33_row2_col1" class="data row2 col1" >12707700.4077</td>
#       <td id="T_0fa33_row2_col2" class="data row2 col2" >3564.7862</td>
#       <td id="T_0fa33_row2_col3" class="data row2 col3" >0.9195</td>
#       <td id="T_0fa33_row2_col4" class="data row2 col4" >0.4106</td>
#       <td id="T_0fa33_row2_col5" class="data row2 col5" >0.2884</td>
#     </tr>
#     <tr>
#       <th id="T_0fa33_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0fa33_row3_col0" class="data row3 col0" >2509.2502</td>
#       <td id="T_0fa33_row3_col1" class="data row3 col1" >22600466.6248</td>
#       <td id="T_0fa33_row3_col2" class="data row3 col2" >4753.9948</td>
#       <td id="T_0fa33_row3_col3" class="data row3 col3" >0.8181</td>
#       <td id="T_0fa33_row3_col4" class="data row3 col4" >0.4097</td>
#       <td id="T_0fa33_row3_col5" class="data row3 col5" >0.2663</td>
#     </tr>
#     <tr>
#       <th id="T_0fa33_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0fa33_row4_col0" class="data row4 col0" >2587.8391</td>
#       <td id="T_0fa33_row4_col1" class="data row4 col1" >25729004.1693</td>
#       <td id="T_0fa33_row4_col2" class="data row4 col2" >5072.3766</td>
#       <td id="T_0fa33_row4_col3" class="data row4 col3" >0.7939</td>
#       <td id="T_0fa33_row4_col4" class="data row4 col4" >0.4917</td>
#       <td id="T_0fa33_row4_col5" class="data row4 col5" >0.3291</td>
#     </tr>
#     <tr>
#       <th id="T_0fa33_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_0fa33_row5_col0" class="data row5 col0" >2356.8918</td>
#       <td id="T_0fa33_row5_col1" class="data row5 col1" >18692251.3315</td>
#       <td id="T_0fa33_row5_col2" class="data row5 col2" >4283.5661</td>
#       <td id="T_0fa33_row5_col3" class="data row5 col3" >0.8610</td>
#       <td id="T_0fa33_row5_col4" class="data row5 col4" >0.4341</td>
#       <td id="T_0fa33_row5_col5" class="data row5 col5" >0.3049</td>
#     </tr>
#     <tr>
#       <th id="T_0fa33_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_0fa33_row6_col0" class="data row6 col0" >213.2743</td>
#       <td id="T_0fa33_row6_col1" class="data row6 col1" >5029113.3370</td>
#       <td id="T_0fa33_row6_col2" class="data row6 col2" >585.9292</td>
#       <td id="T_0fa33_row6_col3" class="data row6 col3" >0.0490</td>
#       <td id="T_0fa33_row6_col4" class="data row6 col4" >0.0420</td>
#       <td id="T_0fa33_row6_col5" class="data row6 col5" >0.0376</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Tune model to lower RMSE
gbr_model_tune = exp.tune_model(gbr_model, optimize='rmse')
# Out:
# <style type="text/css">
# #T_5408b_row5_col0, #T_5408b_row5_col1, #T_5408b_row5_col2, #T_5408b_row5_col3, #T_5408b_row5_col4, #T_5408b_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_5408b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5408b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_5408b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_5408b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_5408b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_5408b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_5408b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5408b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5408b_row0_col0" class="data row0 col0" >3125.4808</td>
#       <td id="T_5408b_row0_col1" class="data row0 col1" >21620420.6525</td>
#       <td id="T_5408b_row0_col2" class="data row0 col2" >4649.7764</td>
#       <td id="T_5408b_row0_col3" class="data row0 col3" >0.8448</td>
#       <td id="T_5408b_row0_col4" class="data row0 col4" >0.4919</td>
#       <td id="T_5408b_row0_col5" class="data row0 col5" >0.3987</td>
#     </tr>
#     <tr>
#       <th id="T_5408b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5408b_row1_col0" class="data row1 col0" >2668.5372</td>
#       <td id="T_5408b_row1_col1" class="data row1 col1" >15067850.6198</td>
#       <td id="T_5408b_row1_col2" class="data row1 col2" >3881.7329</td>
#       <td id="T_5408b_row1_col3" class="data row1 col3" >0.8986</td>
#       <td id="T_5408b_row1_col4" class="data row1 col4" >0.3863</td>
#       <td id="T_5408b_row1_col5" class="data row1 col5" >0.3192</td>
#     </tr>
#     <tr>
#       <th id="T_5408b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5408b_row2_col0" class="data row2 col0" >2653.1491</td>
#       <td id="T_5408b_row2_col1" class="data row2 col1" >15302970.0989</td>
#       <td id="T_5408b_row2_col2" class="data row2 col2" >3911.9011</td>
#       <td id="T_5408b_row2_col3" class="data row2 col3" >0.9031</td>
#       <td id="T_5408b_row2_col4" class="data row2 col4" >0.4066</td>
#       <td id="T_5408b_row2_col5" class="data row2 col5" >0.3084</td>
#     </tr>
#     <tr>
#       <th id="T_5408b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5408b_row3_col0" class="data row3 col0" >3081.7530</td>
#       <td id="T_5408b_row3_col1" class="data row3 col1" >25769407.0989</td>
#       <td id="T_5408b_row3_col2" class="data row3 col2" >5076.3577</td>
#       <td id="T_5408b_row3_col3" class="data row3 col3" >0.7926</td>
#       <td id="T_5408b_row3_col4" class="data row3 col4" >0.4185</td>
#       <td id="T_5408b_row3_col5" class="data row3 col5" >0.2886</td>
#     </tr>
#     <tr>
#       <th id="T_5408b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5408b_row4_col0" class="data row4 col0" >3038.8636</td>
#       <td id="T_5408b_row4_col1" class="data row4 col1" >27286423.9340</td>
#       <td id="T_5408b_row4_col2" class="data row4 col2" >5223.6409</td>
#       <td id="T_5408b_row4_col3" class="data row4 col3" >0.7815</td>
#       <td id="T_5408b_row4_col4" class="data row4 col4" >0.5031</td>
#       <td id="T_5408b_row4_col5" class="data row4 col5" >0.3704</td>
#     </tr>
#     <tr>
#       <th id="T_5408b_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_5408b_row5_col0" class="data row5 col0" >2913.5568</td>
#       <td id="T_5408b_row5_col1" class="data row5 col1" >21009414.4808</td>
#       <td id="T_5408b_row5_col2" class="data row5 col2" >4548.6818</td>
#       <td id="T_5408b_row5_col3" class="data row5 col3" >0.8441</td>
#       <td id="T_5408b_row5_col4" class="data row5 col4" >0.4413</td>
#       <td id="T_5408b_row5_col5" class="data row5 col5" >0.3371</td>
#     </tr>
#     <tr>
#       <th id="T_5408b_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_5408b_row6_col0" class="data row6 col0" >208.2068</td>
#       <td id="T_5408b_row6_col1" class="data row6 col1" >5104848.5686</td>
#       <td id="T_5408b_row6_col2" class="data row6 col2" >564.7198</td>
#       <td id="T_5408b_row6_col3" class="data row6 col3" >0.0510</td>
#       <td id="T_5408b_row6_col4" class="data row6 col4" >0.0472</td>
#       <td id="T_5408b_row6_col5" class="data row6 col5" >0.0410</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# Model doesn't seem to be able to be improved or tuned further

# %%
# Evaluate the model - look at Prediction Error, Feature Selection, and Feature Importance
exp.evaluate_model(gbr_model_tune)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Make predictions on holdout data, model seems to generalize fairly well
exp.predict_model(gbr_model_tune)
# Out:
# <style type="text/css">
# </style>
# <table id="T_eb8e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb8e3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_eb8e3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_eb8e3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_eb8e3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_eb8e3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_eb8e3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_eb8e3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb8e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb8e3_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_eb8e3_row0_col1" class="data row0 col1" >2548.6876</td>
#       <td id="T_eb8e3_row0_col2" class="data row0 col2" >23231631.7939</td>
#       <td id="T_eb8e3_row0_col3" class="data row0 col3" >4819.9203</td>
#       <td id="T_eb8e3_row0_col4" class="data row0 col4" >0.8094</td>
#       <td id="T_eb8e3_row0_col5" class="data row0 col5" >0.4290</td>
#       <td id="T_eb8e3_row0_col6" class="data row0 col6" >0.3011</td>
#     </tr>
#   </tbody>
# </table>
#            age       bmi  children  sex_encoded  smoker_encoded  \
# 143  -0.727521  1.379242         3            0               0
# 930   0.341052 -0.139566         2            1               0
# 570   1.623339  1.050265         1            0               0
# 408  -1.439902 -2.186075         0            1               0
# 540   1.694578  0.956748         0            0               0
# ...        ...       ...       ...          ...             ...
# 1091  0.910958  0.050807         0            0               0
# 539  -1.368664  0.203606         2            0               0
# 51    0.626005 -0.429301         1            1               1
# 1032 -1.226188 -0.282346         0            1               0
# 1283 -1.297426 -1.229201         0            1               0
#
#       region_encoded       charges  prediction_label
# 143                2   5138.256836       6695.053462
# 930                0  32108.662109      10088.837992
# 570                0  31620.001953      16552.874297
# 408                1   1621.340210       1279.283626
# 540                2  13887.204102      14342.758138
# ...              ...           ...               ...
# 1091               0  23045.566406      11913.295285
# 539                2   3056.388184       5462.518918
# 51                 3  23568.271484      24343.105941
# 1032               0   2250.835205       3315.682910
# 1283               2   1515.344849       4036.790554
#
# [266 rows x 8 columns]

# %%
# Finalize model by training on entire dataset (including holdout set)
final_model = exp.finalize_model(gbr_model_tune)

# %%
# Save model
exp.save_model(final_model, 'medical_insurance_prediction_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['age', 'bmi'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['smoker_encoded', 'region_encoded',
#                                               'sex_encoded', 'children'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('ordinal_encoding',
#                   TransformerWrapper(include=[...
#  dtype: int64},
#                                                                          {'col': 'sex_encoded',
#                                                                           'data_type': dtype('float64'),
#                                                                           'mapping': 0.0    0
#  1.0    1
#  NaN   -1
#  dtype: int64}]))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['region_encoded', 'children'],
#                                      transformer=OneHotEncoder(cols=['region_encoded',
#                                                                      'children'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('actual_estimator',
#                   GradientBoostingRegressor(random_state=2136))]),
#  'medical_insurance_prediction_model.pkl')

# %% [markdown]
# # Conclusion
# It appears that the only relevant features are smoker_encoded, BMI, and age. The line of best fit also appears to be about as good as possible.
# There seem to be some entries that deter from the general pattern of the dataset.
# I'm rather happy with this result as the R squared metric is rather high at around 0.85 while the line of best fit covers the pattern of the model very well.
